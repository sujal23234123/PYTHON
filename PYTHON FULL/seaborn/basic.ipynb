# %%
import seaborn as sns

tips=sns.load_dataset("tips")            #load_dataset are the load data in seaborn for practice datasets
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# Differents plots

# %%
#scatter plot
import matplotlib.pyplot as plt
import seaborn as sns

sns.scatterplot(x="tip",y="size",data=tips)
plt.title(" scatter plot of tips vs size plot")
plt.xlabel("tip")
plt.ylabel("size")
# Out:
# Text(0, 0.5, 'size')

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.lineplot(x="day",y="time",data=tips)
plt.title("line plot of day vs time")
plt.xlabel("day")
plt.ylabel("time")
# Out:
# Text(0, 0.5, 'time')

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
#categorical plot(barplot)

import matplotlib.pyplot as plt
import seaborn as sns

sns.barplot(x="day",y="total_bill",data=tips)
plt.title("barplot of day vs total bill")
plt.xlabel("day")
plt.ylabel("total bill")
# Out:
# Text(0, 0.5, 'total bill')

# %%
#box plot

import matplotlib.pyplot as plt
import seaborn as sns

sns.boxplot(x="total_bill",y="smoker",data=tips)
plt.title("box plot of total bill vs smoker")
plt.xlabel("total bill")
plt.ylabel("smoker")
# Out:
# Text(0, 0.5, 'smoker')

# %%
#violin plot

import matplotlib.pyplot as plt
import seaborn as sns

sns.violinplot(x="day",y="tip",data=tips)
plt.title("violin plot of day vs tip")
plt.xlabel("day")
plt.ylabel("tip")
# Out:
# Text(0, 0.5, 'tip')

# %%
#histogram

import matplotlib.pyplot as plt
import seaborn as sns

sns.histplot(tips["total_bill"],bins=10,edgecolor="black",kde=True)
plt.title("hist plot of total bill")
# Out:
# Text(0.5, 1.0, 'hist plot of total bill')

# %%
#pairplot

import matplotlib.pyplot as plt
import seaborn as sns

sns.pairplot(tips)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#correlation and that heatmap 

corr=tips[["total_bill","size","tip"]].corr()
corr

sns.heatmap(corr,annot=True,cmap="coolwarm")
# Out:
# <Axes: >

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

salesdata=pd.read_csv("data.csv")
salesdata.head(5)

sns.barplot(x="Category",y="Sales",data=salesdata,estimator=sum)
plt.title("barplot of category vs sales")
# Out:
# Text(0.5, 1.0, 'barplot of category vs sales')
